# %%
# Pokemon- Weedle's Cave
# Titanic : Machine Learning from Disaster

# %%
# Kaggle arayüz incelemeni yap.
# 1-Basic tools 2- Basic Statistics 3-Data Munging 4- Data visualization 5-Machine Learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("pokemon.csv")

# %%
data.info() # veri seti incelemesi  hp:can  legendary : nesil
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
# correliaton map featurlar arası ilişkiyi anlamamızı sağlar. İki özellik arası 1 ise bunlar doğru orantılı.
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(data.select_dtypes(include=['number']).corr(), annot=True, linewidths=.5, fmt='.1f', ax=ax)
plt.show() # featurlar arası ilişkiy görmek için snn kütüphanesinden heatmap fonksiyonu kullanılır.
# annot yazan sayıların gösterilip gösterilmeyeceğini belirtir.

# %%
data_numeric = data.select_dtypes(include=['number'])
data_numeric.corr()
# Special def artarsa def artıcak yorumunuy apabilriiz.
# 1 e yakın çıkarsa + correalation -1e yakın çıkarsa - correlation 0 çıkarsa bunların arasında ilişki yok
# heatmap bu excel görünümünü görselleştirir.
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097712  0.102664  0.094691  0.089199  0.085596
# HP          0.097712  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102664  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094691  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.089199  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085596  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.012181  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.983428  0.058683  0.051451  0.042419  0.036437  0.028486
#
#                Speed  Generation
# #           0.012181    0.983428
# HP          0.175952    0.058683
# Attack      0.381240    0.051451
# Defense     0.015227    0.042419
# Sp. Atk     0.473018    0.036437
# Sp. Def     0.259133    0.028486
# Speed       1.000000   -0.023121
# Generation -0.023121    1.000000

# %%
data.head(10)
# Out:
#     #              Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   1         Bulbasaur  Grass  Poison  45      49       49       65       65
# 1   2           Ivysaur  Grass  Poison  60      62       63       80       80
# 2   3          Venusaur  Grass  Poison  80      82       83      100      100
# 3   4     Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4   5        Charmander   Fire     NaN  39      52       43       60       50
# 5   6        Charmeleon   Fire     NaN  58      64       58       80       65
# 6   7         Charizard   Fire  Flying  78      84       78      109       85
# 7   8  Mega Charizard X   Fire  Dragon  78     130      111      130       85
# 8   9  Mega Charizard Y   Fire  Flying  78     104       78      159      115
# 9  10          Squirtle  Water     NaN  44      48       65       50       64
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# ...

# %%
data.columns # sahip olduğu featurların adını verir.
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# # 1. INTRODUCTION TO PYTHON

# %% [markdown]
# ### Matplotlib

# %% [markdown]
# Matplot is a python library that help us to plot data. The easiest and basic plots are line, scatter and histogram plots.
# * Line plot is better when x axis is time.
# * Scatter is better when there is correlation between two variables
# * Histogram is better when we need to see distribution of numerical data.
# * Customization: Colors,labels,thickness of line, title, opacity, grid, figsize, ticks of axis and linestyle

# %%
# Line Plot
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = sytle of line
data.Speed.plot(kind = 'line', color = 'r',label = 'Speed',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.Defense.plot(color = 'b',label = 'Defense',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper left')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()
# x ekseni pokemonlar y ekseni de hız ve defans özelliği

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Scatter Plot 
# x = attack, y = defense
data.plot(kind='scatter', x='Attack', y='Defense',alpha = 0.5,color = 'red')
plt.xlabel('Attack')              # label = name of label
plt.ylabel('Defence')
plt.title('Attack Defense Scatter Plot')            # title = title of plot
plt.show()
# iki veri arasındaki ilişkiyi bulmak için

# %%
data.columns
plt.scatter(data.Attack,data.Defense, color="red", alpha=0.8) # bu şekilde de çizdirebiliriz.

# %%
# Histogram
# bins = number of bar in figure
data.Speed.plot(kind = 'hist',bins = 50,figsize = (8,8))
plt.xlabel("speed value")
plt.ylabel("frequency")
# plt.clf() ile çizdirilen plotu clear ederiz
plt.show()

# %% [markdown]
# ### DICTIONARY

# %% [markdown]
# Why we need dictionary?
# * It has 'key' and 'value'
# * Faster than lists
# <br>
# What is key and value. Example:
# * dictionary = {'spain' : 'madrid'}
# * Key is spain.
# * Values is madrid.
# <br>
# <br>**It's that easy.**
# <br>Lets practice some other properties like keys(), values(), update, add, check, remove key, remove all entries and remove dicrionary.

# %%
dictionary = {'spain' : 'madrid','usa' : 'vegas'}
print(dictionary.keys())
print(dictionary.values())
# Out:
# dict_keys(['spain', 'usa'])
# dict_values(['madrid', 'vegas'])

# %%
dictionary['spain'] = "barcelona"    # update existing entry
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas'}

# %%
dictionary['france'] = "paris"       # Add new entry
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas', 'france': 'paris'}

# %%
del dictionary['spain']              # remove entry with key 'spain'
print(dictionary)
# Out:
# {'usa': 'vegas', 'france': 'paris'}

# %%
print('france' in dictionary)        # check include or not
# Out:
# True

# %%
dictionary.clear()                   # remove all entries in dict
print(dictionary)
# Out:
# {}

# %%
# In order to run all code you need to take comment this line
# del dictionary         # delete entire dictionary     
print(dictionary)       # it gives error because dictionary is deleted   
#dictionay memory de yer kaplamasın diye onu siledebiliriz.
# Out:
# {}

# %% [markdown]
# ### PANDAS

# %% [markdown]
# What we need to know about pandas?
# * CSV: comma - separated values

# %%
data = pd.read_csv("pokemon.csv")

# %%
series = data["Defense"]
series
# Out:
# 0       49
# 1       63
# 2       83
# 3      123
# 4       43
#       ...
# 795    150
# 796    110
# 797     60
# 798     60
# 799    120
# Name: Defense, Length: 800, dtype: int64

# %%
print(type(series)) # seriler vektörler gibi tek satırlı uzanırlar dataframeden metotları farklıdır
# Out:
# <class 'pandas.core.series.Series'>

# %%
data_frame = data[["Defense"]]
data_frame
# Out:
#      Defense
# 0         49
# 1         63
# 2         83
# 3        123
# 4         43
# ..       ...
# 795      150
# 796      110
# 797       60
# 798       60
# 799      120
#
# [800 rows x 1 columns]

# %%
print(type(data_frame))
# seri ve dataframe' e nasıl dönüştürüldüğünü  gördük.
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <a id="5"></a> <br>
# Before continue with pandas,   we need to learn **logic, control flow** and **filtering.**
# <br>Comparison operator:  ==, <, >, <=
# <br>Boolean operators: and, or ,not
# <br> Filtering pandas

# %%
2==3
# Out:
# False

# %%
# Comparison operator
print(3 > 2)
print(3!=2)
# Out:
# True
# True

# %%
# Boolean operators
print(True and False)
print(True or False)
# Out:
# False
# True

# %%
# 1 - Filtering Pandas data frame
x = data['Defense']>200     # There are only 3 pokemons who have higher defense value than 200
data[x]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 230  231       Shuckle    Bug    Rock  20      10      230       10      230
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 230      5           2      False
# 333     50           3      False

# %%
data["Defense"]>200
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Defense, Length: 800, dtype: bool

# %%
# 2 - Filtering pandas with logical_and
# There are only 2 pokemons who have higher defence value than 2oo and higher attack value than 100
data[np.logical_and(data['Defense']>200, data['Attack']>100 )]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
# This is also same with previous code line. Therefore we can also use '&' for filtering.
data[(data['Defense']>200) & (data['Attack']>100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %% [markdown]
# ### WHILE and FOR LOOPS

# %% [markdown]
# We will learn most basic while and for loops

# %%
# Stay in loop if condition( i is not equal 5) is true
i = 0
while i != 5 :
    print('i is: ',i)
    i +=1 
print(i,' is equal to 5')
# Out:
# i is:  0
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# 5  is equal to 5

# %%
# Stay in loop if condition( i is not equal 5) is true
lis = [1,2,3,4,5]
for i in lis:
    print('i is: ',i)
print('')
# Out:
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5

# %%
# Enumerate index and value of list
# index : value = 0:1, 1:2, 2:3, 3:4, 4:5
for index, value in enumerate(lis):
    print(index," : ",value)
print('')     # HEM İNDEX HEM VALUE KULLANMAK İSTİYORSAN
# Out:
# 0  :  1
# 1  :  2
# 2  :  3
# 3  :  4
# 4  :  5

# %%
# For dictionaries
# We can use for loop to achive key and value of dictionary. We learnt key and value at dictionary part.
dictionary = {'spain':'madrid','france':'paris'}
for key,value in dictionary.items():
    print(key," : ",value)
print('')
# Out:
# spain  :  madrid
# france  :  paris

# %%
# For pandas we can achieve index and value
for index,value in data[['Attack']][0:5].iterrows():
    print(index," : ",value)
# iterrows ile attack featurenın value ve indexine ulaşırız
# Out:
# 0  :  Attack    49
# Name: 0, dtype: int64
# 1  :  Attack    62
# Name: 1, dtype: int64
# 2  :  Attack    82
# Name: 2, dtype: int64
# 3  :  Attack    100
# Name: 3, dtype: int64
# 4  :  Attack    52
# Name: 4, dtype: int64

# %% [markdown]
# In this part, you learn:
# * how to import csv file
# * plotting line,scatter and histogram
# * basic dictionary features
# * basic pandas features like filtering that is actually something always used and main for being data scientist
# * While and for loops

# %%
# Bitcoin Historical Data
# Coordinate Reference Systems dataları ile çalışabilirsin.

# %% [markdown]
# # 2. PYTHON DATA SCIENCE TOOLBOX

# %% [markdown]
# ### USER DEFINED FUNCTION

# %% [markdown]
# What we need to know about functions:
# * docstrings: documentation for functions. Example:
# <br>for f():   Fonksiyonun  ne yaptığını anlatan comment gibi  bir şey
#     <br>"""This is docstring for documentation of function f"""
# * tuble: sequence of immutable python objects.
# <br>cant modify values
# <br>tuble uses paranthesis like tuble = (1,2,3)
# <br>unpack tuble into several variables like a,b,c = tuble

# %%
# example of what we learn above
def tuble_ex():
    """ return defined t tuble"""
    t = (1,2,3)
    return t
a,b,c = tuble_ex()
print(a,b,c)
_,b,c = tuble_ex()
# Out:
# 1 2 3

# %%
### SCOPE

# %% [markdown]
# What we need to know about scope:
# * global: defined main body in script
# * local: defined in a function
# * built in scope: names in predefined built in scope module such as print, len
# <br><br>Lets make some basic examples

# %%
# guess print what
x = 2
def f():
    x = 3
    return x
print(x)      # x = 2 global scope
print(f())    # x = 3 local scope
#global herkesin eriştiği, local metodun içinde kullanılan
# Out:
# 2
# 3

# %%
# What if there is no local scope
x = 5
def f():
    y = 2*x        # there is no local scope x
    return y
print(f())         # it uses global scope x
# First local scopesearched, then global scope searched, if two of them cannot be found lastly built in scope searched.
# Out:
# 10

# %%
# How can we learn what is built in scope
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
# Soru
a = 3
def f(x,y):
    a=5
    return x*(y+a)
f(2,4)
# Out:
# 18

# %% [markdown]
# ### NESTED FUNCTION
# * function inside function. İç içe yazılmış fonksiyon
# * There is a LEGB rule that is search local scope, enclosing function, global and built in scopes, respectively.

# %%
#nested function
def square():
    """ return square of value """
    def add():
        """ add two local variable """
        x = 2
        y = 3
        z = x + y
        return z
    return add()**2
print(square())
# Out:
# 25

# %% [markdown]
# ### DEFAULT and FLEXIBLE ARGUMENTS
# * Default argument example:
# <br> def f(a, b=1):
#         """ b = 1 is default argument"""
# * Flexible argument example:
# <br> def f(*args):
#        """ *args can be one or more"""
# <br>def f(** kwargs)
#        """ **kwargs is a dictionary"""
#
# <br><br> lets write some code to practice

# %%
# default arguments
def f(a, b = 1, c = 2):
    y = a + b + c
    return y
print(f(5))
# what if we want to change default arguments
print(f(5,4,3))
# Out:
# 8
# 12

# %%
# flexible arguments *args
def f(*args):
    for i in args:
        print(i)
f(1)
print("")
f(1,2,3,4)
# Out:
# 1
#
# 1
# 2
# 3
# 4

# %%
# flexible arguments **kwargs that is dictionary
def f(**kwargs):
    """ print key and value of dictionary"""
    for key, value in kwargs.items():               # If you do not understand this part turn for loop part and look at dictionary in for loop
        print(key, " ", value)
f(country = 'spain', capital = 'madrid', population = 123456)
# Out:
# country   spain
# capital   madrid
# population   123456

# %% [markdown]
# ### LAMBDA FUNCTION
# Faster way of writing function
# Fonksiyon yazmanın  kısa ve hızlı yolu

# %%
def square(x):
    a =x*x
    return a
deneme = square(4)
print(deneme)
# Out:
# 16

# %%
square = lambda x: x**2     # where x is name of argument
print(square(4))
# Out:
# 16

# %%
tot = lambda x,y,z: x+y+z   # where x,y,z are names of arguments
print(tot(1,2,3))
# Out:
# 6

# %% [markdown]
# ### ANONYMOUS FUNCTİON
# Like lambda function but it can take more than one arguments.
# * map(func,seq) : applies a function to all the items in a list
# * Lambda fonksiyonu gibidr. Birden fazla argüman  alabilir.
# * map : liste içindekileri teker teker lambda fonksiyonu içine sokar

# %%
number_list = [1,2,3]
y = map(lambda x:x**2,number_list)
print(list(y))
# Out:
# [1, 4, 9]

# %%
#soru
def  sum(a,b):
    def sub(a,b):
        return a-b
    return sub(a,b)+2
sum(3,1)
# Out:
# 4

# %%
#soru
def s(x, y=2):
    return x**2
s(2)
# Out:
# 4

# %%
s(2,3)
# Out:
# 4

# %%
#Soru
def f(*args):
    for i in args:
        print(i)
f(3,5,7)
# Out:
# 3
# 5
# 7

# %%
# Soru 
tot =lambda x,y,z : x*y**z
print(tot(1,2,3))
# Out:
# 8

# %%
# Soru 
number_list =[1,2,3]
y=map(lambda x:x**3,number_list)
print(list(y))
# Out:
# [1, 8, 27]

# %% [markdown]
# ### ITERATORS
# * iterable is an object that can return an iterator
# * iterable: an object with an associated iter() method
# <br> example: list, strings and dictionaries
# * iterator: produces next value with next() method
# * iterable objesine itereter yapıyorduk yani list strings dictionaries bunlar iterabledır.

# %%
# iteration example
name = "ronaldo"
it = iter(name)
print(next(it))    # print next iteration
print(*it)         # print remaining iteration
# Out:
# r
# o n a l d o

# %%
# zip example
list1 = [1,2,3,4]
list2 = [5,6,7,8]
z = zip(list1,list2)
print(z)

# %%
z_list = list(z)
print(z_list)
# Out:
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
# zip metodu çok kullanılır. index değer mantığında ve birleştirmek için kullanılır. 
#

# %%
un_zip = zip(*z_list)
un_list1,un_list2 = list(un_zip) # unzip returns tuble
print(un_list1)
print(un_list2)
print(type(un_list2))
# Out:
# (1, 2, 3, 4)
# (5, 6, 7, 8)
# <class 'tuple'>

# %%
# unzip yaparken python bunları tupplea çeviriyor. 
print(type(list(un_list1)))
# Out:
# <class 'list'>

# %% [markdown]
# ### LIST COMPREHENSİON
# **One of the most important topic of this kernel**
# <br>We use list comprehension for data analysis often.
# <br> list comprehension: collapse for loops for building lists into a single line
# <br>Ex: num1 = [1,2,3] and we want to make it num2 = [2,3,4]. This can be done with for loop. However it is  unnecessarily long. We can make it one line code that is list comprehension.
# İteratörler önemli bir konu değilken bu konu önemlidir.

# %%
# Example of list comprehension
num1 = [1,2,3]
num2 = [i + 1 for i in num1 ]
print(num2)

# num1 iterable for döngüsü de iter burda
#iterable objemi iterater ile iterasyon yaptım
# Out:
# [2, 3, 4]

# %% [markdown]
# [i + 1 for i in num1 ]: list of comprehension
# <br> i +1: list comprehension syntax
# <br> for i in num1: for loop syntax
# <br> i: iterator
# <br> num1: iterable object

# %%
# Conditionals on iterable
num1 = [5,10,15]
num2 = [i**2 if i == 10 else i-5 if i < 7 else i+5 for i in num1]
print(num2)
# Out:
# [0, 100, 20]

# %%
print(sum)
# Out:
# <function sum at 0x0000028750AE2AC0>

# %%
del sum

# %%
# lets return pokemon csv and make one more list comprehension example
# lets classify pokemons whether they have high or low speed. Our threshold is average speed.
threshold = sum(data.Speed)/len(data.Speed) # pokemon hız ortalaması
print(threshold)
data["speed_level"] = ["high" if i > threshold else "low" for i in data.Speed]
data.loc[:10,["speed_level","Speed"]] # we will learn loc more detailed later
# Out:
# 68.2775
#    speed_level  Speed
# 0          low     45
# 1          low     60
# 2         high     80
# 3         high     80
# 4          low     65
# 5         high     80
# 6         high    100
# 7         high    100
# 8         high    100
# 9          low     43
# 10         low     58

# %% [markdown]
# # 3.CLEANING DATA

# %% [markdown]
# ### DIAGNOSE DATA for CLEANING
# We need to diagnose and clean data before exploring.
# <br>Unclean data:
# * Column name inconsistency like upper-lower case letter or space between words
# * missing data : bir verinin değerinin olmaması - none
# * different language : farklı diller içeren veri
# * diagnose : datadaki temiz olmayan unclean olan şeyleri tespit etmek
# * Biri büyük, biri küçük ya da yazı ile sayı arasında boşluk var .Bunlar istenilmeyen şeyler.
# *
#
# <br> We will use head, tail, columns, shape and info methods to diagnose data

# %%
data = pd.read_csv("pokemon.csv")
data.head() # head shows first 5 rows
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# tail shows last 5 rows
data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
# en başta index satırı  var silinebilir.

# %%
data.columns # columns gives column names of features
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape   # shape gives number of rows and columns in a tuble
# 800 satır 12 sütün (feature)
# Out:
# (800, 12)

# %%
# info gives data type like dataframe, number of sample or row, number of feature or column, feature types and memory usage
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
# type 2'si olmayan 386 obje var

# %% [markdown]
# <a id="18"></a> <br>
# ### EXPLORATORY DATA ANALYSIS
# value_counts(): Frequency counts
# <br>outliers: the value that is considerably higher or lower from rest of the data
# * Lets say value at 75% is Q3 and value at 25% is Q1.
# * Outlier are smaller than Q1 - 1.5(Q3-Q1) and bigger than Q3 + 1.5(Q3-Q1). (Q3-Q1) = IQR
# <br>We will use describe() method. Describe method includes:
# * count: number of entries
# * mean: average of entries
# * std: standart deviation
# * min: minimum entry
# * 25%: first quantile
# * 50%: median or second quantile
# * 75%: third quantile
# * max: maximum entry
#
# <br> What is quantile?
#
# * 1,4,5,6,8,9,11,12,13,14,15,16,17
# * The median is the number that is in **middle** of the sequence. In this case it would be 11.
#
# * The lower quartile is the median in between the smallest number and the median i.e. in between 1 and 11, which is 6.
# * The upper quartile, you find the median between the median and the largest number i.e. between 11 and 17, which will be 14 according to the question above.
#
#
# - Outliers : Aykırı , medyan : serinin ortasındaki sayı , 1-11 arasındaki medyan 6 , lower quartile =q1 = %25 , upper quartile = q3  = %75
# - dataya  göre çok düşük ya da çok yüksek olan aykırı dataya denir
# - describe metodu ile bunu nasıl hesaplarıza bakalım
# -

# %%
# For example lets look frequency of pokemom types
print(data['Type 1'].value_counts(dropna =False))  # if there are nan values that also be counted
# As it can be seen below there are 112 water pokemon or 70 grass pokemon
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
# data type 1 içindeki değerlerin sıklığını sayıyor. Mesela 800 pokemonun içinde 112 tane su pokemonu varmış.
# value.counts() : çok kullanılan metotlardan bir tanesidir.

# %%
# For example max HP is 255 or min defense is 5
data.describe() #ignore null entries
# sadece numerik değerleri verir
# 50 olan değer ortalama değer değil ortadaki değerdir.
# mean varken medyan hesaplama sebebi ---> 1,1,1,1,1000  ort : 200 medyan : 1  patron ort maasa gore zam yaparsa haksızık olur
# medyanın 1 olması demek bu şirketten çalışanların %50si 1 den düşük alıyor demek
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %% [markdown]
# ### VISUAL EXPLORATORY DATA ANALYSIS
# * Box plots: visualize basic statistics like outliers, min/max or quantiles

# %%
# For example: compare attack of pokemons that are legendary  or not
# Black line at top is max
# Blue line at top is 75%
# Red line is median (50%)
# Blue line at bottom is 25%
# Black line at bottom is min
# There are no outliers
data.boxplot(column='Attack',by = 'Legendary') # Pokemonların atağını efsane olup olmadığına göre plot ettirmek istiyoruz.
# Out:
# <Axes: title={'center': 'Attack'}, xlabel='Legendary'>

# %%
# 1.5 IQR üzerindeki değer ve altındaki değer outlierdır.

# %% [markdown]
# ### TIDY DATA
# We tidy data with melt().
# Describing melt is confusing. Therefore lets make example to understand it.
# melt fonksiyonu pandas kütüphanesinin bir fonksiyonudur.

# %%
# Firstly I create new data from pokemons data to explain melt nore easily.
data_new = data.head()    # I only take 5 rows into new data
data_new
# yeni datayı ilk 5 datayı alarak oluşturduk.
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# lets melt
# id_vars = what we do not wish to melt
# value_vars = what we want to melt
melted = pd.melt(frame=data_new,id_vars = 'Name', value_vars= ['Attack','Defense'])
melted
# melt etmek yukarıdaki tablodan belirli değerleri alarak değerler sabit kalacak şekilde yeni bir tablo oluşturmaktır.
# id_vars : yeni datadan değişmeden kalmasını istedğim variable "name" . Her bir pokemonu ismine göre melt edicem.
# melt : default olarak variable ve value tanımlıdır.
# seabornda datayı görselleştirmek için melt etmek gereklidir.
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %% [markdown]
# <a id="21"></a> <br>
# ### PIVOTING DATA
# Reverse of melting.
# Melti eski haline getirme

# %%
# Index is name
# I want to make that columns are variable
# Finally values in columns are value
melted.pivot(index = 'Name', columns = 'variable',values='value')
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %% [markdown]
# <a id="22"></a> <br>
# ### CONCATENATING DATA
# We can concatenate two dataframe
# İki farklı dataframe'i birleştirebiliriz.

# %%
# Firstly lets create 2 data frame
data1 = data.head()
data2= data.tail()
conc_data_row = pd.concat([data1,data2],axis =0,ignore_index =True) # axis = 0 : adds dataframes in row
conc_data_row
# ignore_index = True ile yeni index ata diyorum.
#axis=0 ile yatay birleştirme
# Out:
#      #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1       Bulbasaur    Grass  Poison  45      49       49       65
# 1    2         Ivysaur    Grass  Poison  60      62       63       80
# 2    3        Venusaur    Grass  Poison  80      82       83      100
# 3    4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4    5      Charmander     Fire     NaN  39      52       43       60
# 5  796         Diancie     Rock   Fairy  50     100      150      100
# 6  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 7  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 8  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 9  800       Volcanion     Fire   Water  80     110      120      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
data1 = data['Attack'].head()
data2= data['Defense'].head()
conc_data_col = pd.concat([data1,data2],axis =1) # axis = 0 : adds dataframes in row
conc_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %% [markdown]
# <a id="23"></a> <br>
# ### DATA TYPES
# There are 5 basic data types: object(string),boolean,  integer, float and categorical.
# <br> We can make conversion data types like from str to categorical or from int to float
# <br> Why is category important:
# * make dataframe smaller in memory
# * can be utilized for anlaysis especially for sklear(we will learn later)

# %%
data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
# lets convert object(str) to categorical and int to float.
data['Type 1'] = data['Type 1'].astype('category')
data['Speed'] = data['Speed'].astype('float')

# %%
# As you can see Type 1 is converted from object to categorical
# And Speed ,s converted from int to float
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %%
# bu metotu çok kullanıcaz defence mesela string olarak verilmiş int çevirmek gerekli gibi

# %% [markdown]
# <a id="24"></a> <br>
# ### MISSING DATA and TESTING WITH ASSERT
# If we encounter with missing data, what we can do:
# * leave as is ---> Öylece bırakabiliriz
# * drop them with dropna() ----> missing value olanları datasetinden çıkarabiliriz.
# * fill missing value with fillna() ----> boş missngleri nan ile doldurabiliriz.
# * fill missing values with test statistics like mean ---> sayısal bir şey ise diğer örneklerin ortalaması ile doldurabilriz.
# <br>Assert statement: check that you can turn on or turn off when you are done with your testing of the program

# %%
data.head(10)  # nan değerler missing datadır
# charmender type 2 gerçekten mi yok yoksa buraya mı yazılmadı
# Out:
#     #              Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   1         Bulbasaur  Grass  Poison  45      49       49       65       65
# 1   2           Ivysaur  Grass  Poison  60      62       63       80       80
# 2   3          Venusaur  Grass  Poison  80      82       83      100      100
# 3   4     Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4   5        Charmander   Fire     NaN  39      52       43       60       50
# 5   6        Charmeleon   Fire     NaN  58      64       58       80       65
# 6   7         Charizard   Fire  Flying  78      84       78      109       85
# 7   8  Mega Charizard X   Fire  Dragon  78     130      111      130       85
# 8   9  Mega Charizard Y   Fire  Flying  78     104       78      159      115
# 9  10          Squirtle  Water     NaN  44      48       65       50       64
#
#    Speed  Generation  Legendary
# 0   45.0           1      False
# 1   60.0           1      False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    category
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
# 386 tane pokemonun type 2 si yok

# %%
# Lets chech Type 2
data["Type 2"].value_counts(dropna =False)  # false diyerek drop etme bunlları da say dedik
# As you can see, there are 386 NAN value
# Out:
# Type 2
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: count, dtype: int64

# %%
# Lets drop nan values
data1=data   # also we will use data to fill missing value so I assign it to data1 variable
data1["Type 2"].dropna(inplace = True)  # inplace = True means we do not assign it to new variable. Changes automatically assigned to data
# So does it work ?


#data 1 içine kaydedecek inplace true ile

# %%
#  Lets check with assert statement
# Assert statement:
assert 1==1 # return nothing because it is true
# bunu assert ettik yukarıdaki işlemi test etmek için ctrl enter ile run edince hüçbir şey döndürmedi o zaman bu işlem doğru deriiz

# %%
# In order to run all code, we need to make this line comment
 #assert 1==2 # return error because it is false

# %%
# assert çalışma mantığı bu şekilde datamıza uygulayalım bu mantığı

# %%
assert  data1['Type 2'].notnull().all() # returns nothing because we drop nan values # notnull ile boş varmı diye sorduk
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[230], line 1
# ----> 1 assert  data1['Type 2'].notnull().all()
#
# AssertionError:

# %% [markdown]
# 🔍 Ne yapar?
#
# assert bir kontrol (doğrulama) ifadesidir.
# Python şunu der:
#
# “Eğer parantez içindeki ifade True değilse, hata (AssertionError) ver.”
#
# 🔸 Yani bu durumda:
#
# data1['Type 2'].notnull().all()
# → True olur = Tüm değerler doluysa
# → False olur = En az bir NaN varsa
#
# 🔸 Dolayısıyla:
#
# Eğer sütunda hala eksik (NaN) bir değer varsa,
# bu ifade False döner ve assert bunu yakalar:
#
# AssertionError

# %%
data["Type 2"] = data["Type 2"].fillna('empty')

# %%
assert  data['Type 2'].notnull().all() # returns nothing because we do not have nan values

# %%
# # With assert statement we can check a lot of thing. For example
# assert data.columns[1] == 'Name'
# assert data.Speed.dtypes == np.int
#  assert metodunu test içinde kullanabiliriz. İlk data columnu name döndürüyoruz doğru hiçbir şey döndürmez hata vermez 
#

# %% [markdown]
# In this part, you learn:
# * Diagnose data for cleaning
# * Exploratory data analysis
# * Visual exploratory data analysis
# * Tidy data
# * Pivoting data
# * Concatenating data
# * Data types
# * Missing data and testing with assert

# %% [markdown]
# <a id="25"></a> <br>
# # 4. PANDAS FOUNDATION

# %% [markdown]
# <a id="26"></a> <br>
# ### REVİEW of PANDAS
# As you notice, I do not give all idea in a same time. Although, we learn some basics of pandas, we will go deeper in pandas.
# * single column = series
# * NaN = not a number
# * dataframe.values = numpy

# %% [markdown]
# <a id="27"></a> <br>
# ### BUILDING DATA FRAMES FROM SCRATCH
# * We can build data frames from csv as we did earlier.
# * Also we can build dataframe from dictionaries
#     * zip() method: This function returns a list of tuples, where the i-th tuple contains the i-th element from each of the argument sequences or iterables.
# * Adding new column
# * Broadcasting: Create new column and assign a value to entire column
# * Dataframeleri csv formatından build etmiştik, dataframe dictionartden nasıl build edilir ona bakıcaz

# %%
# data frames from dictionary
country = ["Spain","France"]
population = ["11","12"]
list_label = ["country","population"]
list_col = [country,population]
zipped = list(zip(list_label,list_col))
zipped
# Out:
# [('country', ['Spain', 'France']), ('population', ['11', '12'])]

# %%
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
# Add new columns
df["capital"] = ["madrid","paris"]
df
# Out:
#   country population capital
# 0   Spain         11  madrid
# 1  France         12   paris

# %%
# Broadcasting
df["income"] = 0 #Broadcasting entire column
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   paris       0

# %% [markdown]
# ### VISUAL EXPLORATORY DATA ANALYSIS
# * Plot
# * Subplot
# * Histogram:
#     * bins: number of bins
#     * range(tuble): min and max values of bins
#     * normed(boolean): normalize or not
#     * cumulative(boolean): compute cumulative distribution

# %%
# Plotting all data 
data1 = data.loc[:,["Attack","Defense","Speed"]]
data1.plot()
# it is confusing
# Out:
# <Axes: >

# %%
# subplots
data1.plot(subplots = True)
plt.show()

# %%
# scatter plot  
data1.plot(kind = "scatter",x="Attack",y = "Defense")
plt.show()

# %%
# hist plot
data1.plot(kind="hist", y="Defense", bins=50, range=(0, 250), density=True)
#density = true ile data normalizce edilir
# Out:
# <Axes: ylabel='Frequency'>

# %%
# histogram subplot with non cumulative and cumulative
fig, axes = plt.subplots(nrows=2,ncols=1)
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),density = True,ax = axes[0])
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),density = True,ax = axes[1],cumulative = True)
plt.savefig('graph.png')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# cumulative = True da olaslıkları toplaya toplaya gider

# %% [markdown]
# ### STATISTICAL EXPLORATORY DATA ANALYSIS
# I already explained it at previous parts. However lets look at one more time.
# * count: number of entries
# * mean: average of entries
# * std: standart deviation
# * min: minimum entry
# * 25%: first quantile
# * 50%: median or second quantile
# * 75%: third quantile
# * max: maximum entry

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %% [markdown]
# ### INDEXING PANDAS TIME SERIES
# * datetime = object
# * parse_dates(boolean): Transform date to ISO 8601 (yyyy-mm-dd hh:mm:ss ) format

# %%
# time serilerin özellikleri  indexlerinin time serilerden oluşması . datetime veri tipidir. Pokemon serimizde time series olmadığı için time eklemek zorundayız.

# %%
time_list = ["1992-03-08","1992-04-12"] # bunlar şu an datetime objesi değil string
print(type(time_list[1])) # As you can see date is string
# however we want it to be datetime object
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire   empty  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0   45.0           1      False
# 1   60.0           1      False
# 2   80.0           1      False
# 3   80.0           1      False
# 4   65.0           1      False

# %%
#baştaki indexi datetime objeye değiştirelim

# %%
# close warning
import warnings
warnings.filterwarnings("ignore")
# In order to practice lets take head of pokemon data and add it a time list
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
# lets make date as index
data2= data2.set_index("date")
data2
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-10  1      Bulbasaur  Grass  Poison  45      49       49       65
# 1992-02-10  2        Ivysaur  Grass  Poison  60      62       63       80
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire   empty  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       65   45.0           1      False
# 1992-02-10       80   60.0           1      False
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
# datam time series data oldu

# %%
# Now we can select according to our date index
print(data2.loc["1993-03-16"])
# Out:
# #                      5
# Name          Charmander
# Type 1              Fire
# Type 2             empty
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed               65.0
# Generation             1
# Legendary          False
# Name: 1993-03-16 00:00:00, dtype: object

# %%
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire   empty  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %% [markdown]
# ### RESAMPLING PANDAS TIME SERIES
# * Resampling: statistical method over different time intervals
#     * Needs string to specify frequency like "M" = month or "A" = year ----> m harfini kullanarak istediğimiz ayları resample edebiliriz a harfi yılları vb.
#     * Yıla göre  resample yap  ve hızın ortalamasını bul mesela
# * Downsampling: reduce date time rows to slower frequency like from daily to weekly
# * Upsampling: increase date time rows to faster frequency like from daily to hourly
# * Interpolate: Interpolate values according to different methods like ‘linear’, ‘time’ or index’
#     * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.interpolate.html
#
# - Datanın  içinden elde ettiğimiz yeni örneklere resampling denir.

# %%
# We will use data2 that we create at previous part
data2.select_dtypes(include=["float64", "int64"]).resample("A").mean()
# Out:
#               #         HP     Attack  Defense    Sp. Atk    Sp. Def  \
# date
# 1992-12-31  2.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  4.5  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation
# date
# 1992-12-31  61.666667         1.0
# 1993-12-31  72.500000         1.0

# %%
# Lets resample with month
data2.select_dtypes(include=["float64", "int64"]).resample("M").mean()
# As you can see there are a lot of nan because data2 does not include all months
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# date
# 1992-01-31  1.0  45.0    49.0     49.0     65.0     65.0   45.0         1.0
# 1992-02-29  2.0  60.0    62.0     63.0     80.0     80.0   60.0         1.0
# 1992-03-31  3.0  80.0    82.0     83.0    100.0    100.0   80.0         1.0
# 1992-04-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-05-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-06-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-07-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-08-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-09-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-10-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-11-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# ...

# %%
# In real life (data is real. Not created from us like data2) we can solve this problem with interpolate
# We can interpolete from first value
data2.select_dtypes(include=["float64", "int64"]).resample("M").first().interpolate("linear") # nümerik olan değerleri interpolate ile dolduruyoruz
# Out:
#                    #    HP  Attack     Defense     Sp. Atk     Sp. Def  Speed  \
# date
# 1992-01-31  1.000000  45.0    49.0   49.000000   65.000000   65.000000   45.0
# 1992-02-29  2.000000  60.0    62.0   63.000000   80.000000   80.000000   60.0
# 1992-03-31  3.000000  80.0    82.0   83.000000  100.000000  100.000000   80.0
# 1992-04-30  3.083333  80.0    83.5   86.333333  101.833333  101.666667   80.0
# 1992-05-31  3.166667  80.0    85.0   89.666667  103.666667  103.333333   80.0
# 1992-06-30  3.250000  80.0    86.5   93.000000  105.500000  105.000000   80.0
# 1992-07-31  3.333333  80.0    88.0   96.333333  107.333333  106.666667   80.0
# 1992-08-31  3.416667  80.0    89.5   99.666667  109.166667  108.333333   80.0
# 1992-09-30  3.500000  80.0    91.0  103.000000  111.000000  110.000000   80.0
# 1992-10-31  3.583333  80.0    92.5  106.333333  112.833333  111.666667   80.0
# 1992-11-30  3.666667  80.0    94.0  109.666667  114.666667  113.333333   80.0
# ...

# %%
# Or we can interpolate with mean()
data2.select_dtypes(include=["float64", "int64"]).resample("M").mean().interpolate("linear")
# meanleriaynı olacak şekilde interpoalte edilebilir
# Out:
#                 #         HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  \
# date
# 1992-01-31  1.000  45.000000    49.0     49.0    65.00    65.00  45.000
# 1992-02-29  2.000  60.000000    62.0     63.0    80.00    80.00  60.000
# 1992-03-31  3.000  80.000000    82.0     83.0   100.00   100.00  80.000
# 1992-04-30  3.125  78.291667    81.5     83.0    99.25    98.75  79.375
# 1992-05-31  3.250  76.583333    81.0     83.0    98.50    97.50  78.750
# 1992-06-30  3.375  74.875000    80.5     83.0    97.75    96.25  78.125
# 1992-07-31  3.500  73.166667    80.0     83.0    97.00    95.00  77.500
# 1992-08-31  3.625  71.458333    79.5     83.0    96.25    93.75  76.875
# 1992-09-30  3.750  69.750000    79.0     83.0    95.50    92.50  76.250
# 1992-10-31  3.875  68.041667    78.5     83.0    94.75    91.25  75.625
# 1992-11-30  4.000  66.333333    78.0     83.0    94.00    90.00  75.000
# 1992-12-31  4.125  64.625000    77.5     83.0    93.25    88.75  74.375
# ...

# %% [markdown]
# # MANIPULATING DATA FRAMES WITH PANDAS

# %% [markdown]
# ### INDEXING DATA FRAMES
# * Indexing using square brackets
# * Using column attribute and row label
# * Using loc accessor
# * Selecting only some columns

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire   empty  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0   45.0           1      False
# 1   60.0           1      False
# 2   80.0           1      False
# 3   80.0           1      False
# 4   65.0           1      False

# %%
# read data
data = pd.read_csv('pokemon.csv')
data= data.set_index("#") # index 0 dan başlıyordu artık 1 den başlıyor
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
# indexing using square brackets
data["HP"][1] # indexi set etmesek 0 yazacaktık buraya
# Out:
# 45

# %%
# using column attribute and row label
data.HP[1]
# Out:
# 45

# %%
# using loc accessor
data.loc[1,["HP"]]
# Out:
# HP    45
# Name: 1, dtype: object

# %%
# yukarıdaki de 3ü de aynı sonucu verir. Farklı gösterim şekilleridir.

# %%
# Selecting only some columns
data[["HP","Attack"]]
# Out:
#      HP  Attack
# #
# 1    45      49
# 2    60      62
# 3    80      82
# 4    80     100
# 5    39      52
# ..   ..     ...
# 796  50     100
# 797  50     160
# 798  80     110
# 799  80     160
# 800  80     110
#
# [800 rows x 2 columns]

# %% [markdown]
# ### SLICING DATA FRAME
# * Difference between selecting columns
#     * Series and data frames
# * Slicing and indexing series
# * Reverse slicing
# * From something to end
# * Aralık seçme imkanı tanıyordu.

# %%
# Difference between selecting columns: series and dataframes
print(type(data["HP"]))     # series
print(type(data[["HP"]]))   # data frames
#tek köşeli içinde series çift köşeli içinde dataframe
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# Slicing and indexing series
data.loc[1:10,"HP":"Defense"]   # 10 and "Defense" are inclusive
# Out:
#     HP  Attack  Defense
# #
# 1   45      49       49
# 2   60      62       63
# 3   80      82       83
# 4   80     100      123
# 5   39      52       43
# 6   58      64       58
# 7   78      84       78
# 8   78     130      111
# 9   78     104       78
# 10  44      48       65

# %%
# Reverse slicing 
data.loc[10:1:-1,"HP":"Defense"]
# Out:
#     HP  Attack  Defense
# #
# 10  44      48       65
# 9   78     104       78
# 8   78     130      111
# 7   78      84       78
# 6   58      64       58
# 5   39      52       43
# 4   80     100      123
# 3   80      82       83
# 2   60      62       63
# 1   45      49       49

# %%
# From something to end
data.loc[1:10,"Speed":]
# Out:
#     Speed  Generation  Legendary
# #
# 1      45           1      False
# 2      60           1      False
# 3      80           1      False
# 4      80           1      False
# 5      65           1      False
# 6      80           1      False
# 7     100           1      False
# 8     100           1      False
# 9     100           1      False
# 10     43           1      False

# %% [markdown]
# ### FILTERING DATA FRAMES
# Creating boolean series
# Combining filters
# Filtering column based others

# %%
# Creating boolean series
boolean = data.HP > 200
data[boolean]
# Out:
#         Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122  Chansey  Normal    NaN  250       5        5       35      105     50
# 262  Blissey  Normal    NaN  255      10       10       75      135     55
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False

# %%
# Combining filters
first_filter = data.HP > 150
second_filter = data.Speed > 35
data[first_filter & second_filter]
# Out:
#           Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122    Chansey  Normal    NaN  250       5        5       35      105     50
# 262    Blissey  Normal    NaN  255      10       10       75      135     55
# 352    Wailord   Water    NaN  170      90       45       90       45     60
# 656  Alomomola   Water    NaN  165      75       80       40       45     65
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False
# 352           3      False
# 656           5      False

# %%
# Filtering column based others
data.HP[data.Speed<15]
# Out:
# #
# 231     20
# 360     45
# 487     50
# 496    135
# 659     44
# Name: HP, dtype: int64

# %% [markdown]
# ### TRANSFORMING DATA
# * Plain python functions
# * Lambda function: to apply arbitrary python function to every element
# * Defining column using other columns

# %%
# Plain python functions
def div(n):
    return n/2
data.HP.apply(div) # apply ile fonks tüm data setine uygulanır
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
# Or we can use lambda function
data.HP.apply(lambda n : n/2)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
# Defining column using other columns
data["total_power"] = data.Attack + data.Defense
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary  total_power
# #
# 1           1      False           98
# 2           1      False          125
# 3           1      False          165
# 4           1      False          223
# 5           1      False           95

# %% [markdown]
# ### INDEX OBJECTS AND LABELED DATA
# index: sequence of label
# - index ile neler yapabiliriz onlara bakalım

# %%
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary  total_power
# #
# 1           1      False           98
# 2           1      False          125
# 3           1      False          165
# 4           1      False          223
# 5           1      False           95

# %%
# our index name is this:
print(data.index.name)
# Out:
# #

# %%
# lets change it
data.index.name = "index_name"
data.head()
# Out:
#                      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# index_name
# 1               Bulbasaur  Grass  Poison  45      49       49       65
# 2                 Ivysaur  Grass  Poison  60      62       63       80
# 3                Venusaur  Grass  Poison  80      82       83      100
# 4           Mega Venusaur  Grass  Poison  80     100      123      122
# 5              Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary  total_power
# index_name
# 1                65     45           1      False           98
# 2                80     60           1      False          125
# 3               100     80           1      False          165
# 4               120     80           1      False          223
# 5                50     65           1      False           95

# %%
# Overwrite index
# if we want to modify index we need to change all of them.
data.head()
# Out:
#                      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# index_name
# 1               Bulbasaur  Grass  Poison  45      49       49       65
# 2                 Ivysaur  Grass  Poison  60      62       63       80
# 3                Venusaur  Grass  Poison  80      82       83      100
# 4           Mega Venusaur  Grass  Poison  80     100      123      122
# 5              Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary  total_power
# index_name
# 1                65     45           1      False           98
# 2                80     60           1      False          125
# 3               100     80           1      False          165
# 4               120     80           1      False          223
# 5                50     65           1      False           95

# %%
# first copy of our data to data3 then change index 
data3 = data.copy()
# lets make index start from 100. It is not remarkable change but it is just example
data3.index = range(100,900,1)
data3.head()
# Out:
#               Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 100      Bulbasaur  Grass  Poison  45      49       49       65       65
# 101        Ivysaur  Grass  Poison  60      62       63       80       80
# 102       Venusaur  Grass  Poison  80      82       83      100      100
# 103  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 104     Charmander   Fire     NaN  39      52       43       60       50
#
#      Speed  Generation  Legendary  total_power
# 100     45           1      False           98
# 101     60           1      False          125
# 102     80           1      False          165
# 103     80           1      False          223
# 104     65           1      False           95

# %%
# We can make one of the column as index. I actually did it at the beginning of manipulating data frames with pandas section
# It was like this
# data= data.set_index("#")
# also you can use 
# data.index = data["#"]

# %% [markdown]
# ### HIERARCHICAL INDEXING
# * Setting indexing

# %%
# lets read data frame one more time to start from beginning
data = pd.read_csv('pokemon.csv')
data.head()
# As you can see there is index. However we want to set one or more column to be index
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# Setting index : type 1 is outer type 2 is inner index
data1 = data.set_index(["Type 1","Type 2"]) 
data1.head(100)
# data1.loc["Fire","Flying"] # howw to use indexes
# type 1 ve type 2 benim indexlerim oldu
# Out:
#                  #           Name   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Type 2
# Grass  Poison    1      Bulbasaur   45      49       49       65       65
#        Poison    2        Ivysaur   60      62       63       80       80
#        Poison    3       Venusaur   80      82       83      100      100
#        Poison    4  Mega Venusaur   80     100      123      122      120
# Fire   NaN       5     Charmander   39      52       43       60       50
# ...            ...            ...  ...     ...      ...      ...      ...
# Poison NaN      96         Grimer   80      80       50       40       50
#        NaN      97            Muk  105     105       75       65      100
# Water  NaN      98       Shellder   30      65      100       45       25
#        Ice      99       Cloyster   50      95      180       85       45
# Ghost  Poison  100         Gastly   30      35       30      100       35
#
#                Speed  Generation  Legendary
# Type 1 Type 2
# ...

# %% [markdown]
# ### PIVOTING DATA FRAMES
# * pivoting: reshape tool
# * feature olarak kullandığımız isimleri birer value yapcaz demek

# %%
dic = {"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
df = pd.DataFrame(dic)
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
# pivoting
df.pivot(index="treatment",columns = "gender",values="response")
# bu işleme pivoting diyoruz
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %% [markdown]
# ### STACKING and UNSTACKING DATAFRAME
# * deal with multi label indexes  birden fazla indexe sahipleri unstack yapar
# * level: position of unstacked index
# * swaplevel: change inner and outer level index position

# %%
df1 = df.set_index(["treatment","gender"])
df1
# lets unstack it
# Out:
#                   response  age
# treatment gender
# A         F             10   15
#           M             45    4
# B         F              5   72
#           M              9   65

# %%
# level determines indexes
df1.unstack(level=0) 
#indexlerden birinden kurtuluyor gibi bişi
# index 0 ımı indexlikten çıkar
# Out:
#           response    age
# treatment        A  B   A   B
# gender
# F               10  5  15  72
# M               45  9   4  65

# %%
df1.unstack(level=1)
# Out:
#           response     age
# gender           F   M   F   M
# treatment
# A               10  45  15   4
# B                5   9  72  65

# %%
# change inner and outer level index position
df2 = df1.swaplevel(0,1)
df2
# index yerlerini değiştiriyoruz
# Out:
#                   response  age
# gender treatment
# F      A                10   15
# M      A                45    4
# F      B                 5   72
# M      B                 9   65

# %% [markdown]
# ### MELTING DATA FRAMES
# * Reverse of pivoting
# * Pivot meltingin tam tersi

# %%
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
# df.pivot(index="treatment",columns = "gender",values="response")
pd.melt(df,id_vars="treatment",value_vars=["age","response"])
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %% [markdown]
# ### CATEGORICALS AND GROUPBY

# %%
# We will use df
df
#bir şeye göre gruplamak
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
df.groupby("treatment")

# %%
# according to treatment take means of other features
df.groupby("treatment").mean(numeric_only=True)
   # mean is aggregation / reduction method
# there are other methods like sum, std,max or min
#tedaviye göre grupla ve ortlamasını al
# Out:
#            response   age
# treatment
# A              27.5   9.5
# B               7.0  68.5

# %%
# we can only choose one of the feature
df.groupby("treatment").age.max()
# Out:
# treatment
# A    15
# B    72
# Name: age, dtype: int64

# %%
# Or we can choose multiple features
df.groupby("treatment")[["age","response"]].min()
# Out:
#            age  response
# treatment
# A            4        10
# B           65         5

# %%
df.info()
# as you can see gender is object
# However if we use groupby, we can convert it categorical data. 
# Because categorical data uses less memory, speed up operations like groupby
#df["gender"] = df["gender"].astype("category")
#df["treatment"] = df["treatment"].astype("category")
#df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   treatment  4 non-null      object
#  1   gender     4 non-null      object
#  2   response   4 non-null      int64
#  3   age        4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes
